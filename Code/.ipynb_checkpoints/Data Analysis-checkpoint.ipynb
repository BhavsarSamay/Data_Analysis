# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
axis=pd.read_csv('C:/Users/jainam/Stock Analysis/Data/AXISBANK.NS_data.csv')
hdfc=pd.read_csv('C:/Users/jainam/Stock Analysis/Data/HDFCBANK.NS_data.csv')
icici=pd.read_csv('C:/Users/jainam/Stock Analysis/Data/ICICIBANK.NS_data.csv')
indusind=pd.read_csv('C:/Users/jainam/Stock Analysis/Data/INDUSINDBK.NS_data.csv')
kotak=pd.read_csv('C:/Users/jainam/Stock Analysis/Data/KOTAKBANK.NS_data.csv')
index=pd.read_csv('C:/Users/jainam/Stock Analysis/Data/Bank Nifty.csv')

# %%
indusind
# Out:
#             Date         Open         High          Low        Close   Volume  \
# 0     02-01-2012   210.626578   213.708922   207.590940   211.513916   282144
# 1     03-01-2012   213.895740   228.560205   213.895740   226.598724   358725
# 2     04-01-2012   226.038299   229.260743   221.601597   227.112442   274822
# 3     05-01-2012   226.925627   232.389781   224.590520   230.848602   329318
# 4     06-01-2012   229.727751   231.268930   223.329569   225.010834   482808
# ...          ...          ...          ...          ...          ...      ...
# 2708  26-12-2022  1137.520814  1194.891429  1128.618477  1182.724854  2100374
# 2709  27-12-2022  1188.610379  1196.820239  1172.141031  1189.302734  1462244
# 2710  28-12-2022  1184.999958  1213.685266  1181.043364  1200.974731  2834356
# 2711  29-12-2022  1192.913173  1221.499590  1188.758797  1217.790283  3134405
# 2712  30-12-2022  1224.565890  1224.565890  1198.353454  1206.860107  1767556
#
# ...

# %%
axis.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2713.000000  2713.000000  2713.000000  2713.000000  2.713000e+03
# mean    509.256091   515.986199   501.895643   508.881763  1.140448e+07
# std     189.709163   191.388582   187.708308   189.584723  9.846975e+06
# min     150.136891   151.983046   146.202098   148.216110  0.000000e+00
# 25%     381.351587   388.658382   373.686102   381.469330  5.980728e+06
# 50%     513.679181   520.510298   506.050294   512.384644  8.492688e+06
# 75%     668.881887   676.969512   659.096731   669.480957  1.273670e+07
# max     953.099976   958.900024   940.450012   949.750000  1.205419e+08
#
#          Dividends  Stock Splits
# count  2713.000000   2713.000000
# mean      0.010100      0.001843
# std       0.203294      0.095994
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       0.000000      0.000000
# max       5.000000      5.000000

# %%
hdfc.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2713.000000  2713.000000  2713.000000  2713.000000  2.713000e+03
# mean    806.983111   814.525512   798.852806   806.909696  6.111296e+06
# std     429.303522   433.305547   425.089564   429.209869  6.235225e+06
# min     196.197136   196.608832   191.897178   195.259384  0.000000e+00
# 25%     405.169179   407.888435   401.160676   405.825500  2.887592e+06
# 50%     801.318356   808.296901   794.555797   803.199463  4.680690e+06
# 75%    1170.290319  1179.967232  1159.579781  1168.240356  7.363362e+06
# max    1666.294921  1685.840902  1633.066723  1650.364868  2.011300e+08
#
#          Dividends  Stock Splits
# count  2713.000000   2713.000000
# mean      0.022512      0.000737
# std       0.420091      0.038398
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       0.000000      0.000000
# max      15.500000      2.000000

# %%
icici.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2713.000000  2713.000000  2713.000000  2713.000000  2.713000e+03
# mean    354.290411   358.630383   349.712990   354.197042  1.963869e+07
# std     203.762944   205.646806   201.948135   203.875111  1.367965e+07
# min     108.731874   110.204946   107.936255   109.740181  0.000000e+00
# 25%     210.217769   212.538927   207.351822   209.840744  1.167039e+07
# 50%     281.481704   284.766409   277.799675   281.319122  1.622785e+07
# 75%     419.496933   424.559069   413.265737   418.887695  2.327538e+07
# max     956.000000   958.200012   941.000000   952.900024  2.868577e+08
#
#          Dividends  Stock Splits
# count  2713.000000   2713.000000
# mean      0.014694      0.002248
# std       0.227895      0.098282
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       0.000000      0.000000
# max       5.000000      5.000000

# %%
indusind.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2713.000000  2713.000000  2713.000000  2713.000000  2.713000e+03
# mean    946.798784   959.606802   932.645327   945.948191  4.030340e+06
# std     452.831793   456.494594   448.502240   452.405926  7.386122e+06
# min     210.626578   213.708922   207.590940   211.513916  0.000000e+00
# 25%     508.431003   517.285764   499.345004   508.375793  8.564370e+05
# 50%     910.809338   921.237976   899.322920   910.003479  1.602574e+06
# 75%    1307.433227  1318.173930  1279.821459  1300.549438  3.557219e+06
# max    1974.731452  1979.490801  1945.932654  1964.969971  8.133499e+07
#
#          Dividends  Stock Splits
# count  2713.000000        2713.0
# mean      0.021821           0.0
# std       0.365879           0.0
# min       0.000000           0.0
# 25%       0.000000           0.0
# 50%       0.000000           0.0
# 75%       0.000000           0.0
# max       8.500000           0.0

# %%
kotak.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2713.000000  2713.000000  2713.000000  2713.000000  2.713000e+03
# mean   1022.097738  1034.090977  1009.002010  1021.925771  2.544894e+06
# std     558.359823   564.493335   551.512466   557.964217  3.208591e+06
# min     211.262997   215.235076   207.588897   209.401138  0.000000e+00
# 25%     521.350708   527.799197   515.375406   521.699219  1.237058e+06
# 50%     972.908475   981.025322   963.877856   972.050293  1.887671e+06
# 75%    1504.346887  1521.078536  1486.763840  1506.444580  2.950616e+06
# max    2198.676280  2251.644390  2175.290457  2209.619629  8.385990e+07
#
#          Dividends  Stock Splits
# count  2713.000000   2713.000000
# mean      0.002248      0.000737
# std       0.039917      0.038398
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       0.000000      0.000000
# max       1.100000      2.000000

# %%
index.describe()
# Out:
#                Open          High           Low         Close          P/B
# count   4256.000000   4256.000000   4256.000000   5623.000000  5623.000000
# mean   16326.298790  16466.047171  16163.354852  12750.077402     2.236066
# std     9861.139384   9919.350113   9785.840579  10642.712243     0.724953
# min     3385.400000   3446.750000   3314.550000    743.700000     0.770000
# 25%     8808.162500   8915.500000   8646.000000   3718.750000     1.780000
# 50%    12563.450000  12671.200000  12458.375000  10058.000000     2.350000
# 75%    24305.525000  24414.637500  24097.525000  19355.500000     2.770000
# max    41234.550000  41829.600000  40829.150000  41238.300000     4.730000

# %%
stock_df_all=axis,hdfc,icici,indusind,kotak,index
stock_df=pd.concat(stock_df_all,ignore_index = True)

# %%
stock_df.duplicated().sum()
# Out:
# 0

# %%
closing_price_over_years = px.line(stock_df, x=stock_df["Date"], y=stock_df["Close"], title='Price Variation',color=stock_df['Symbol'])
closing_price_over_years.show()
# Out:
# <div>                            <div id="0ba28fbd-17b7-4fbe-a652-5641b22c0811" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ba28fbd-17b7-4fbe-a652-5641b22c0811")) {                    Plotly.newPlot(                        "0ba28fbd-17b7-4fbe-a652-5641b22c0811",                        [{"hovertemplate":"Symbol=AXISBANK<br>Date=%{x}<br>Close=%{y}<extra></extra>","legendgroup":"AXISBANK","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"AXISBANK","showlegend":true,"x":["02-01-2012","03-01-2012","04-01-2012","05-01-2012","06-01-2012","09-01-2012","10-01-2012","11-01-2012","12-01-2012","13-01-2012","16-01-2012","17-01-2012","18-01-2012","19-01-2012","20-01-2012","23-01-2012","24-01-2012","25-01-2012","27-
# ...

# %%
index=pd.read_csv("C:/Users/jainam/Stock Analysis/Data/NIFTY BANK_Data.csv")

# %%
closing_price_over_years = px.line(index, x="Date", y="Close", title='Price Variation')
closing_price_over_years.show()

# %%
close=plt.plot(hdfc['Date'],hdfc['Close'])

# %%
plt.plot(hdfc['Date '][::300], hdfc['close '][::300])
plt.show()

# %%
df = hdfc.sort_values(by='Date ')

# Create a Plotly trace
trace = px.line(x=df['Date '][::300], y=df['close '][::300])
# Show plot
trace.show()
